# %% [markdown]
# # [Sign language dactyl recognition based on machine learning algorithms](https://www.researchgate.net/publication/354349413_Sign_language_dactyl_recognition_based_on_machine_learning_algorithms)

# %%
import numpy as np 
import pandas as pd 
import glob
import os
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import keras
from sklearn.preprocessing import LabelEncoder

# %%
TEST_DATA_PATH = '/Users/kamilla/Desktop/masters_diploma/SOTA_MODELS/SOTA_3/data_SOTA_3/green_images/green_test_01_06_mp_2'
TRAIN_DATA_PATH = '/Users/kamilla/Desktop/masters_diploma/SOTA_MODELS/SOTA_3/data_SOTA_3/green_images/green_train_01_06_mp_2'
#VAL_DATA_PATH = '/Users/kamilla/Desktop/masters_diploma/SOTA_MODELS/SOTA_3/data_SOTA_3/temp_val'

# Создадим датафрейм, где будем сохранять путь до картинки и ее лейбл

dactyl = ["А", "Б", "В", "Г", "Е",
          "Ж", "И", "К", "Л", "М",
          "Н", "О", "П", "Р", "С",
          "Т", "У", "Ф", "Х", "Ч",
          "Ш", "Ы", "Э", "Ю", "Я"]

def get_metadata(data_path):
    list_path = []
    list_labels = []
    for label in dactyl:
        label_path = os.path.join(data_path, label, "*")
        image_files = glob.glob(label_path)

        sign_label = [label] * len(image_files)

        list_path.extend(image_files)
        list_labels.extend(sign_label)

    metadata = pd.DataFrame({
        "image_path": list_path,
        "label": list_labels
    })
    return metadata

train_df = get_metadata(TRAIN_DATA_PATH)
print(f"DataFrame for train is ready. Processed {len(train_df)}")
test_df = get_metadata(TEST_DATA_PATH)
print(f"DataFrame for test is ready. Processed {len(test_df)}")
#val_df = get_metadata(VAL_DATA_PATH)
#print(f"DataFrame for val is ready. Processed {len(val_df)}")
# Out:
# DataFrame for train is ready. Processed 2339
# DataFrame for test is ready. Processed 259

# %%
y_train, x_train = train_df['label'], train_df['image_path']
y_test, x_test = test_df['label'], test_df['image_path']
#y_val, x_val = val_df['label'], val_df['image_path']

# %%
le = LabelEncoder()
le.fit(y_train)
y_train_encoded = le.transform(y_train)
y_train_cat = keras.utils.to_categorical(y_train_encoded)

y_test_encoded = le.transform(y_test)
y_test_cat = keras.utils.to_categorical(y_test_encoded)

#y_val_encoded = le.transform(y_val_prep)
#y_val_cat = keras.utils.to_categorical(y_val_encoded)

# %%
def load_and_preprocess_image(image_path, target_size=(28,28)):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image_array = np.array(image.flatten())
    return image_array

x_train_images = []
for image_path in x_train:
    image_array = load_and_preprocess_image(image_path)
    x_train_images.append(image_array)
x_train_images = np.array(x_train_images)

x_test_images = []
for image_path in x_test:
    image_array = load_and_preprocess_image(image_path)
    x_test_images.append(image_array)
x_test_images = np.array(x_test_images)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# train the model on train set 
model_SVM = SVC() 
model_SVM.fit(x_train_images, y_train_encoded) 

# print prediction results 
#predictions = model.predict(x_test_images) 
#print(classification_report(y_test_encoded, predictions))
# Out:
# SVC()

# %%
predictions = model_SVM.predict(x_test_images) 
print(classification_report(y_test_encoded, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.81        11
#            1       0.82      0.82      0.82        11
#            2       1.00      1.00      1.00        11
#            3       0.88      0.78      0.82         9
#            4       0.89      0.80      0.84        10
#            5       1.00      0.90      0.95        10
#            6       0.90      0.75      0.82        12
#            7       0.75      0.55      0.63        11
#            8       0.38      0.50      0.43        10
#            9       0.71      0.50      0.59        10
#           10       0.59      0.91      0.71        11
#           11       1.00      0.50      0.67         8
#           12       0.45      0.50      0.48        10
#           13       0.50      0.60      0.55        10
#           14       1.00      0.70      0.82        10
#           15       0.54      0.64      0.58        11
#           16       0.89      0.80      0.84        10
#           17       1.00      0.90      0.95        10
#           18       0.75      0.90      0.82        10
#           19       0.90      0.82      0.86        11
#           20       0.53      0.80      0.64        10
#           21       1.00      0.50      0.67        10
#           22       1.00      1.00      1.00        13
#           23       1.00      0.89      0.94         9
#           24       0.67      0.73      0.70        11
#
#     accuracy                           0.76       259
#    macro avg       0.79      0.75      0.76       259
# weighted avg       0.79      0.76      0.76       259

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_encoded, predictions, average='weighted')
recall = recall_score(y_test_encoded, predictions, average='weighted')
f1 = f1_score(y_test_encoded, predictions, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.7925099426149845
# Recall: 0.7567567567567568
# F1-score: 0.7606897152009934

# %%
# Попробуем поменять параметры 
from sklearn.model_selection import GridSearchCV 
  
# defining parameter range 
param_grid = {'C': [0.0001, 0.001, 0.01, 0.1],  
              'gamma': [0.0001, 0.001, 0.01, 0.1], 
              'kernel': ['poly', 'linear']}  
  
grid_SVM = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
grid_SVM.fit(x_train_images, y_train_encoded)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END C=0.0001, gamma=0.0001, kernel=poly;, score=0.374 total time=  37.0s
# [CV 2/5] END C=0.0001, gamma=0.0001, kernel=poly;, score=0.380 total time=  29.5s
# [CV 3/5] END C=0.0001, gamma=0.0001, kernel=poly;, score=0.368 total time=  27.7s
# [CV 4/5] END C=0.0001, gamma=0.0001, kernel=poly;, score=0.331 total time=  24.8s
# [CV 5/5] END C=0.0001, gamma=0.0001, kernel=poly;, score=0.409 total time=  26.7s
# [CV 1/5] END C=0.0001, gamma=0.0001, kernel=linear;, score=0.744 total time=  16.4s
# [CV 2/5] END C=0.0001, gamma=0.0001, kernel=linear;, score=0.752 total time=  12.3s
# [CV 3/5] END C=0.0001, gamma=0.0001, kernel=linear;, score=0.722 total time=  11.9s
# [CV 4/5] END C=0.0001, gamma=0.0001, kernel=linear;, score=0.774 total time=  11.8s
# [CV 5/5] END C=0.0001, gamma=0.0001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END C=0.0001, gamma=0.001, kernel=poly;, score=0.382 total time=  13.7s
# [CV 2/5] END C=0.0001, gamma=0.001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END C=0.0001, gamma=0.001, kernel=poly;, score=0.380 total time=  14.2s
# [CV 4/5] END C=0.0001, gamma=0.001, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END C=0.0001, gamma=0.001, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END C=0.0001, gamma=0.001, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.0001, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.0001, gamma=0.001, kernel=linear;, score=0.722 total time=  11.6s
# [CV 4/5] END C=0.0001, gamma=0.001, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.0001, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END .C=0.0001, gamma=0.01, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END .C=0.0001, gamma=0.01, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END .C=0.0001, gamma=0.01, kernel=poly;, score=0.380 total time=  13.9s
# [CV 4/5] END .C=0.0001, gamma=0.01, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END .C=0.0001, gamma=0.01, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END C=0.0001, gamma=0.01, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.0001, gamma=0.01, kernel=linear;, score=0.752 total time=  11.7s
# [CV 3/5] END C=0.0001, gamma=0.01, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END C=0.0001, gamma=0.01, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.0001, gamma=0.01, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ..C=0.0001, gamma=0.1, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ..C=0.0001, gamma=0.1, kernel=poly;, score=0.378 total time=  13.9s
# [CV 3/5] END ..C=0.0001, gamma=0.1, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ..C=0.0001, gamma=0.1, kernel=poly;, score=0.338 total time=  14.1s
# [CV 5/5] END ..C=0.0001, gamma=0.1, kernel=poly;, score=0.398 total time=  14.0s
# [CV 1/5] END C=0.0001, gamma=0.1, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.0001, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.0001, gamma=0.1, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END C=0.0001, gamma=0.1, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.0001, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END C=0.001, gamma=0.0001, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END C=0.001, gamma=0.0001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END C=0.001, gamma=0.0001, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END C=0.001, gamma=0.0001, kernel=poly;, score=0.338 total time=  13.7s
# [CV 5/5] END C=0.001, gamma=0.0001, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END C=0.001, gamma=0.0001, kernel=linear;, score=0.744 total time=  11.7s
# [CV 2/5] END C=0.001, gamma=0.0001, kernel=linear;, score=0.752 total time=  12.0s
# [CV 3/5] END C=0.001, gamma=0.0001, kernel=linear;, score=0.722 total time=  12.1s
# [CV 4/5] END C=0.001, gamma=0.0001, kernel=linear;, score=0.774 total time=  11.8s
# [CV 5/5] END C=0.001, gamma=0.0001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END .C=0.001, gamma=0.001, kernel=poly;, score=0.382 total time=  13.9s
# [CV 2/5] END .C=0.001, gamma=0.001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END .C=0.001, gamma=0.001, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END .C=0.001, gamma=0.001, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END .C=0.001, gamma=0.001, kernel=poly;, score=0.398 total time=  13.9s
# [CV 1/5] END C=0.001, gamma=0.001, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.001, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.001, gamma=0.001, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END C=0.001, gamma=0.001, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.001, gamma=0.001, kernel=linear;, score=0.752 total time=  11.7s
# [CV 1/5] END ..C=0.001, gamma=0.01, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ..C=0.001, gamma=0.01, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ..C=0.001, gamma=0.01, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ..C=0.001, gamma=0.01, kernel=poly;, score=0.338 total time=  13.7s
# [CV 5/5] END ..C=0.001, gamma=0.01, kernel=poly;, score=0.398 total time=  13.9s
# [CV 1/5] END C=0.001, gamma=0.01, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.001, gamma=0.01, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.001, gamma=0.01, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END C=0.001, gamma=0.01, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.001, gamma=0.01, kernel=linear;, score=0.752 total time=  11.7s
# [CV 1/5] END ...C=0.001, gamma=0.1, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ...C=0.001, gamma=0.1, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ...C=0.001, gamma=0.1, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ...C=0.001, gamma=0.1, kernel=poly;, score=0.338 total time=  13.9s
# [CV 5/5] END ...C=0.001, gamma=0.1, kernel=poly;, score=0.398 total time=  13.9s
# [CV 1/5] END .C=0.001, gamma=0.1, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END .C=0.001, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END .C=0.001, gamma=0.1, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END .C=0.001, gamma=0.1, kernel=linear;, score=0.774 total time=  11.8s
# [CV 5/5] END .C=0.001, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END .C=0.01, gamma=0.0001, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END .C=0.01, gamma=0.0001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END .C=0.01, gamma=0.0001, kernel=poly;, score=0.380 total time=  13.9s
# [CV 4/5] END .C=0.01, gamma=0.0001, kernel=poly;, score=0.338 total time=  13.9s
# [CV 5/5] END .C=0.01, gamma=0.0001, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END C=0.01, gamma=0.0001, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.01, gamma=0.0001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.01, gamma=0.0001, kernel=linear;, score=0.722 total time=  11.6s
# [CV 4/5] END C=0.01, gamma=0.0001, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.01, gamma=0.0001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ..C=0.01, gamma=0.001, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ..C=0.01, gamma=0.001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ..C=0.01, gamma=0.001, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ..C=0.01, gamma=0.001, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END ..C=0.01, gamma=0.001, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END C=0.01, gamma=0.001, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.01, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.01, gamma=0.001, kernel=linear;, score=0.722 total time=  11.6s
# [CV 4/5] END C=0.01, gamma=0.001, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.01, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ...C=0.01, gamma=0.01, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ...C=0.01, gamma=0.01, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ...C=0.01, gamma=0.01, kernel=poly;, score=0.380 total time=  14.1s
# [CV 4/5] END ...C=0.01, gamma=0.01, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END ...C=0.01, gamma=0.01, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.752 total time=  11.7s
# [CV 3/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ....C=0.01, gamma=0.1, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ....C=0.01, gamma=0.1, kernel=poly;, score=0.378 total time=  13.9s
# [CV 3/5] END ....C=0.01, gamma=0.1, kernel=poly;, score=0.380 total time=  13.9s
# [CV 4/5] END ....C=0.01, gamma=0.1, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END ....C=0.01, gamma=0.1, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.752 total time=  11.7s
# [CV 3/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.338 total time=  13.7s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.744 total time=  11.5s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.380 total time=  13.8s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.752 total time=  11.6s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.382 total time=  13.8s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.378 total time=  13.8s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.380 total time=  13.7s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.338 total time=  13.8s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.398 total time=  13.8s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.744 total time=  11.6s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.722 total time=  11.5s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.774 total time=  11.7s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.752 total time=  11.6s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1],
#                          'gamma': [0.0001, 0.001, 0.01, 0.1],
#                          'kernel': ['poly', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning 
print(grid_SVM.best_params_) 
# print how our model looks after hyper-parameter tuning 
print(grid_SVM.best_estimator_) 
grid_predictions_SVM = grid_SVM.predict(x_test_images)   
# print classification report 
print(classification_report(y_test_encoded, grid_predictions_SVM))
# Out:
# {'C': 0.0001, 'gamma': 0.0001, 'kernel': 'linear'}
# SVC(C=0.0001, gamma=0.0001, kernel='linear')
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        11
#            1       0.73      0.73      0.73        11
#            2       0.79      1.00      0.88        11
#            3       0.90      1.00      0.95         9
#            4       0.88      0.70      0.78        10
#            5       1.00      0.80      0.89        10
#            6       0.80      0.67      0.73        12
#            7       0.45      0.45      0.45        11
#            8       0.40      0.60      0.48        10
#            9       0.78      0.70      0.74        10
#           10       0.64      0.82      0.72        11
#           11       0.86      0.75      0.80         8
#           12       0.50      0.50      0.50        10
#           13       0.70      0.70      0.70        10
#           14       0.91      1.00      0.95        10
#           15       0.56      0.45      0.50        11
#           16       0.82      0.90      0.86        10
#           17       0.90      0.90      0.90        10
#           18       0.78      0.70      0.74        10
#           19       0.75      0.82      0.78        11
#           20       0.80      0.80      0.80        10
#           21       1.00      0.60      0.75        10
#           22       1.00      1.00      1.00        13
#           23       1.00      0.89      0.94         9
#           24       0.64      0.64      0.64        11
#
#     accuracy                           0.76       259
#    macro avg       0.78      0.76      0.76       259
# weighted avg       0.77      0.76      0.76       259

# %% [markdown]
# # RandomForest

# %%
RANDOM_STATE = 128

# %%
from sklearn.ensemble import RandomForestClassifier


model_RFC = RandomForestClassifier(random_state=RANDOM_STATE) 
model_RFC.fit(x_train_images, y_train_encoded) 

# print prediction results 
predictions_RFC = model_RFC.predict(x_test_images) 
print(classification_report(y_test_encoded, predictions_RFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76        11
#            1       0.71      0.91      0.80        11
#            2       0.91      0.91      0.91        11
#            3       0.89      0.89      0.89         9
#            4       1.00      0.90      0.95        10
#            5       1.00      0.90      0.95        10
#            6       0.82      0.75      0.78        12
#            7       0.57      0.73      0.64        11
#            8       0.64      0.70      0.67        10
#            9       0.88      0.70      0.78        10
#           10       0.67      0.91      0.77        11
#           11       1.00      0.38      0.55         8
#           12       0.62      0.50      0.56        10
#           13       1.00      0.40      0.57        10
#           14       0.89      0.80      0.84        10
#           15       0.64      0.64      0.64        11
#           16       0.77      1.00      0.87        10
#           17       0.91      1.00      0.95        10
#           18       0.82      0.90      0.86        10
#           19       1.00      1.00      1.00        11
#           20       0.88      0.70      0.78        10
#           21       1.00      0.60      0.75        10
#           22       1.00      0.92      0.96        13
#           23       0.90      1.00      0.95         9
#           24       0.69      0.82      0.75        11
#
#     accuracy                           0.80       259
#    macro avg       0.83      0.80      0.80       259
# weighted avg       0.83      0.80      0.80       259

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_encoded, predictions_RFC, average='weighted')
recall = recall_score(y_test_encoded, predictions_RFC, average='weighted')
f1 = f1_score(y_test_encoded, predictions_RFC, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.8289557503843218
# Recall: 0.803088803088803
# F1-score: 0.7984903373070568

# %%
param_grid = { 
    'n_estimators': [100,300,400],
    'max_features': ['sqrt'],
    'max_depth' : [1,2,5,10,30],
    'criterion' :['gini', 'entropy']
}

grid_RFC = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3) 
grid_RFC.fit(x_train_images, y_train_encoded)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.254 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.256 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.246 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.267 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.223 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.286 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.256 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.209 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.269 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.261 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.299 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.269 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.214 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.263 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.227 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.425 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.451 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.353 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.404 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.463 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.436 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.412 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.404 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.429 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.471 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.459 total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.425 total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.389 total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.432 total time=   1.4s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.469 total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.645 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.654 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.588 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.690 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.664 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.665 total time=   2.2s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.682 total time=   2.3s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.613 total time=   2.2s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.726 total time=   2.2s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.662 total time=   2.2s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.660 total time=   2.9s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.690 total time=   2.9s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.628 total time=   2.9s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.720 total time=   2.9s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.675 total time=   2.9s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.724 total time=   1.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.759 total time=   1.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.705 total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.780 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.762 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.761 total time=   4.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.765 total time=   4.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.709 total time=   4.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.812 total time=   4.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.775 total time=   4.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.763 total time=   5.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.776 total time=   5.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.746 total time=   5.4s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.803 total time=   5.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.788 total time=   5.4s
# [CV 1/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.744 total time=   1.8s
# [CV 2/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.791 total time=   1.8s
# [CV 3/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.752 total time=   1.8s
# [CV 4/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.829 total time=   1.8s
# [CV 5/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.805 total time=   1.8s
# [CV 1/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.788 total time=   5.4s
# [CV 2/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.806 total time=   5.4s
# [CV 3/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.778 total time=   5.4s
# [CV 4/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.829 total time=   5.4s
# [CV 5/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.827 total time=   5.4s
# [CV 1/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.808 total time=   7.2s
# [CV 2/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.816 total time=   7.3s
# [CV 3/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.784 total time=   7.2s
# [CV 4/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.842 total time=   7.2s
# [CV 5/5] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.812 total time=   7.2s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.252 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.276 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.218 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.248 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.238 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.276 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.261 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.233 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.271 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=300;, score=0.240 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.306 total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.278 total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.241 total time=   1.2s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.267 total time=   1.2s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=400;, score=0.246 total time=   1.2s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.408 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.389 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.447 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.449 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.435 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.395 total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.425 total time=   1.6s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.429 total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.462 total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=300;, score=0.467 total time=   1.6s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.419 total time=   2.1s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.415 total time=   2.1s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.417 total time=   2.1s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.438 total time=   2.1s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=400;, score=0.458 total time=   2.1s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.656 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.697 total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.647 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.697 total time=   1.3s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.694 total time=   1.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.665 total time=   3.9s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.722 total time=   3.9s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.662 total time=   3.9s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.735 total time=   3.9s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=300;, score=0.700 total time=   3.9s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.665 total time=   5.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.707 total time=   5.1s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.645 total time=   5.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.733 total time=   5.1s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=400;, score=0.707 total time=   5.2s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.737 total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.788 total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.729 total time=   2.5s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.803 total time=   2.5s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.809 total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.767 total time=   7.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.825 total time=   7.4s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.784 total time=   7.4s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.831 total time=   7.5s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=300;, score=0.805 total time=   7.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.786 total time=   9.9s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.812 total time=  10.0s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.791 total time=   9.8s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.838 total time=  10.0s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.820 total time=  10.0s
# [CV 1/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.748 total time=   2.7s
# [CV 2/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.806 total time=   2.7s
# [CV 3/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.741 total time=   2.6s
# [CV 4/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.799 total time=   2.7s
# [CV 5/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.777 total time=   2.7s
# [CV 1/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.784 total time=   8.0s
# [CV 2/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.808 total time=   8.0s
# [CV 3/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.795 total time=   7.9s
# [CV 4/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.848 total time=   8.0s
# [CV 5/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.829 total time=   8.0s
# [CV 1/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.788 total time=  10.6s
# [CV 2/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.814 total time=  10.6s
# [CV 3/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.803 total time=  10.6s
# [CV 4/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.840 total time=  10.8s
# [CV 5/5] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=400;, score=0.833 total time=  10.5s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 5, 10, 30],
#                          'max_features': ['sqrt'],
#                          'n_estimators': [100, 300, 400]},
#              verbose=3)

# %%
# print best parameter after tuning 
print(grid_RFC.best_params_) 
# print how our model looks after hyper-parameter tuning 
print(grid_RFC.best_estimator_) 
grid_predictions_RFC = grid_RFC.best_estimator_.predict(x_test_images)   
# print classification report 
print(classification_report(y_test_encoded, grid_predictions_RFC))
# Out:
# {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 400}
# RandomForestClassifier(criterion='entropy', max_depth=30, n_estimators=400)
#               precision    recall  f1-score   support
#
#            0       0.62      0.91      0.74        11
#            1       0.75      0.82      0.78        11
#            2       1.00      0.91      0.95        11
#            3       1.00      1.00      1.00         9
#            4       0.89      0.80      0.84        10
#            5       1.00      0.90      0.95        10
#            6       0.77      0.83      0.80        12
#            7       0.73      0.73      0.73        11
#            8       0.55      0.60      0.57        10
#            9       0.67      0.40      0.50        10
#           10       0.73      1.00      0.85        11
#           11       1.00      0.50      0.67         8
#           12       1.00      0.50      0.67        10
#           13       0.86      0.60      0.71        10
#           14       0.91      1.00      0.95        10
#           15       0.80      0.73      0.76        11
#           16       1.00      1.00      1.00        10
#           17       0.83      1.00      0.91        10
#           18       0.67      0.80      0.73        10
#           19       1.00      1.00      1.00        11
#           20       0.90      0.90      0.90        10
#           21       0.88      0.70      0.78        10
#           22       0.87      1.00      0.93        13
#           23       1.00      1.00      1.00         9
#           24       0.64      0.82      0.72        11
#
#     accuracy                           0.82       259
#    macro avg       0.84      0.82      0.82       259
# weighted avg       0.84      0.82      0.82       259

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import classification_report


xgb_model = xgb.XGBClassifier(objective="multi:softprob", random_state=42)
xgb_model.fit(x_train_images, y_train_encoded)

y_pred_XGB = xgb_model.predict(x_test_images)

print(classification_report(y_test_encoded, y_pred_XGB))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        11
#            1       0.79      1.00      0.88        11
#            2       0.85      1.00      0.92        11
#            3       0.90      1.00      0.95         9
#            4       0.89      0.80      0.84        10
#            5       0.90      0.90      0.90        10
#            6       0.90      0.75      0.82        12
#            7       0.60      0.55      0.57        11
#            8       0.55      0.60      0.57        10
#            9       0.88      0.70      0.78        10
#           10       0.79      1.00      0.88        11
#           11       0.75      0.38      0.50         8
#           12       0.62      0.50      0.56        10
#           13       0.62      0.80      0.70        10
#           14       0.91      1.00      0.95        10
#           15       0.89      0.73      0.80        11
#           16       1.00      0.90      0.95        10
#           17       0.82      0.90      0.86        10
#           18       0.73      0.80      0.76        10
#           19       0.77      0.91      0.83        11
#           20       0.67      0.80      0.73        10
#           21       0.88      0.70      0.78        10
#           22       0.86      0.92      0.89        13
#           23       1.00      0.89      0.94         9
#           24       0.70      0.64      0.67        11
#
#     accuracy                           0.80       259
#    macro avg       0.81      0.80      0.80       259
# weighted avg       0.81      0.80      0.80       259

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_encoded, y_pred_XGB, average='weighted')
recall = recall_score(y_test_encoded, y_pred_XGB, average='weighted')
f1 = f1_score(y_test_encoded, y_pred_XGB, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.8094014736871878
# Recall: 0.803088803088803
# F1-score: 0.7990863220509586

# %%
params = {
    'n_estimators': [100,300],  # Количество деревьев в ансамбле
    'max_depth': [3, 9],             # Максимальная глубина дерева
    'learning_rate': [0.1, 0.01, 0.001],# Скорость обучения
}

grid_XGB = GridSearchCV(xgb.XGBClassifier(objective="multi:softprob"), params, refit=True, verbose=2) 
grid_XGB.fit(x_train_images, y_train_encoded)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=  41.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=  43.7s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=  40.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=  41.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=  41.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time= 1.9min
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time= 1.8min
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time= 1.7min
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time= 1.8min
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time= 1.8min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time= 1.1min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time= 1.1min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time= 1.1min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time= 1.2min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time= 1.2min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=300; total time= 2.1min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=300; total time= 2.2min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=300; total time= 2.1min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=300; total time= 2.2min
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=300; total time= 2.1min
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=  38.6s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=  40.9s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=  39.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=  38.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=  40.8s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time= 2.1min
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time= 2.7min
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time= 2.4min
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time= 2.9min
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time= 2.5min
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=97.0min
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=16.5min
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time= 1.9min
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time= 1.6min
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time= 1.4min
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=300; total time= 4.8min
# [CV] END .learning_rate=0.01, max_depth=9, n_estimators=300; total time=198.1min
# [CV] END .learning_rate=0.01, max_depth=9, n_estimators=300; total time=483.0min

# %%
# print best parameter after tuning 
print(grid_XGB.best_params_) 
# print how our model looks after hyper-parameter tuning 
print(grid_XGB.best_estimator_) 
grid_predictions_XGB = grid_XGB.best_estimator_.predict(x_test_images)   
# print classification report 
print(classification_report(y_test_encoded, grid_predictions_XGB))
